# %% [markdown]
# 🛰️ MintPy Daily-Use Code Repository — OpenSARLab Edition
# Kernel Requirement: Every cell in this notebook must use the osl_mintpy kernel.
# Check and switch it in the top-right corner of your Jupyter interface.
# The default Python 3 kernel will fail with ModuleNotFoundError.

# %% [markdown]
# Universal Path Setup — Run This First in Every Session
#
# **What it does:** Declares a master `DATA_DIR` variable pointing to your MintPy output folder.
# All 18 snippets below depend on this variable. Run this cell first, every time.

# %%
import os

# Change this to your actual MintPy geo-coded output folder in OpenSARLab.
# Typical OpenSARLab paths begin with /home/jovyan/
DATA_DIR = "/home/jovyan/dhaka/HyP3_downloads/MintPy"

# Verify the path actually exists before proceeding
if not os.path.isdir(DATA_DIR):
    raise FileNotFoundError(f"DATA_DIR not found: {DATA_DIR}\nCheck your path and try again.")

print(f"✅ Data directory confirmed: {DATA_DIR}")
# Out:
# ✅ Data directory confirmed: /home/jovyan/dhaka/HyP3_downloads/MintPy

# %% [markdown]
# 12 — Export Velocity Map as a Google Earth KMZ File
# What it does: Creates a compressed .kmz file overlaying your deformation map on Google Earth's 3D globe.
# When to use: For stakeholder presentations, field visit planning, or quick geographic context checks in Google Earth Pro
# Note: These scripts read data from DATA_DIR but save output files into the folder where your .ipynb notebook currently lives, unless you specify an absolute output path.

# %%
from mintpy.cli import save_kmz

file_path = f"{DATA_DIR}/velocity.h5"
output_path = f"{DATA_DIR}/regional_displacement.kmz"

save_kmz.main([file_path, '-o', output_path])
print(f"✅ KMZ saved to: {output_path}")
# Out:
# data   coverage in y/x: (0, 0, 249, 314)
# subset coverage in y/x: (0, 0, 249, 314)
# update LENGTH, WIDTH, Y/XMAX
# update/add SUBSET_XMIN/YMIN/XMAX/YMAX: 0/0/249/314
# update Y/X_FIRST
# update REF_Y/X
# read mask from file: maskTempCoh.h5
# masking out pixels with zero value in file: None
# colormap: jet
# plotting data ...
# figure size : [12.0, 15.1]
# show reference point
# writing /home/jovyan/dhaka/HyP3_downloads/MintPy/regional_displacement_data.png with dpi=600
# writing /home/jovyan/dhaka/HyP3_downloads/MintPy/regional_displacement_cbar.png
# writing /home/jovyan/dhaka/HyP3_downloads/MintPy/regional_displacement.kml
# remove /home/jovyan/dhaka/HyP3_downloads/MintPy/regional_displacement.kml
# remove /home/jovyan/dhaka/HyP3_downloads/MintPy/regional_displacement_data.png
# remove /home/jovyan/dhaka/HyP3_downloads/MintPy/regional_displacement_cbar.png
# merged all files to /home/jovyan/dhaka/HyP3_downloads/MintPy/regional_displacement.kmz
# ✅ KMZ saved to: /home/jovyan/dhaka/HyP3_downloads/MintPy/regional_displacement.kmz
