# %% [markdown]
# 🛰️ MintPy Daily-Use Code Repository — OpenSARLab Edition
# Kernel Requirement: Every cell in this notebook must use the osl_mintpy kernel.
# Check and switch it in the top-right corner of your Jupyter interface.
# The default Python 3 kernel will fail with ModuleNotFoundError.

# %% [markdown]
# Universal Path Setup — Run This First in Every Session
#
# **What it does:** Declares a master `DATA_DIR` variable pointing to your MintPy output folder.
# All 18 snippets below depend on this variable. Run this cell first, every time.

# %%
import os

# Change this to your actual MintPy geo-coded output folder in OpenSARLab.
# Typical OpenSARLab paths begin with /home/jovyan/
DATA_DIR = "/home/jovyan/dhaka/HyP3_downloads/MintPy"

# Verify the path actually exists before proceeding
if not os.path.isdir(DATA_DIR):
    raise FileNotFoundError(f"DATA_DIR not found: {DATA_DIR}\nCheck your path and try again.")

print(f"✅ Data directory confirmed: {DATA_DIR}")
# Out:
# ✅ Data directory confirmed: /home/jovyan/dhaka/HyP3_downloads/MintPy

# %% [markdown]
# 9 — Matrix Indices (Row/Col) → Geographic Coordinates (Lat/Lon)
# What it does: Reverse of Snippet 8. Translates an array index back to real-world latitude and longitude.
# When to use: When an automated script flags an anomalous pixel (e.g. maximum subsidence rate) and you need to know exactly where on Earth that pixel sits.

# %%
# from mintpy.objects import coordinate
# from mintpy.utils import readfile

# file_path = f"{DATA_DIR}/velocity.h5"
# meta = readfile.read_attribute(file_path)
# coord = coordinate.coordinate(meta)

# target_row = 450   # replace with your detected row index
# target_col = 320   # replace with your detected col index

# lat, lon = coord.pixel2geo(row=target_row, col=target_col)
# print(f"Row {target_row}, Col {target_col}  →  Lat: {lat:.6f}, Lon: {lon:.6f}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from mintpy.objects import coordinate
#       2 from mintpy.utils import readfile
#       4 file_path = f"{DATA_DIR}/velocity.h5"
#
# ImportError: cannot import name 'coordinate' from 'mintpy.objects' (/home/jovyan/.local/envs/opensarlab_mintpy_recipe_book/lib/python3.11/site-packages/mintpy/objects/__init__.py)
